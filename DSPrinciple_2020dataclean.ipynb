# %%
import pandas as pd

# %%
df = pd.read_csv("pppub20.csv")

# %%
df.head(1)
#display()
# Out:
#                  PERIDNUM  PH_SEQ  P_SEQ  A_LINENO  PF_SEQ  PHF_SEQ  OED_TYP1  \
# 0  8329611509015080901101       1      1         1       1        1         0
#
#    OED_TYP2  OED_TYP3  PERRP  ...  M5G_CBST  M5G_DSCP  CLWK  DEP_STAT  \
# 0         0         0     40  ...         0         0     2         0
#
#    FILEDATE  FILESTAT  LJCW  NOEMP  WECLW  YYYYMM
# 0     31821         2     3      6      6  202003
#
# [1 rows x 840 columns]

# %%
for each in df.columns:
    print(each)
# Out:
# PERIDNUM
# PH_SEQ
# P_SEQ
# A_LINENO
# PF_SEQ
# PHF_SEQ
# OED_TYP1
# OED_TYP2
# OED_TYP3
# PERRP
# PXRRP
# PXMARITL
# PXRACE1
# PEHSPNON
# PXHSPNON
# PEAFEVER
# PXAFEVER
# PEAFWHN1
# PXAFWHN1
# PEAFWHN2
# PEAFWHN3
# PEAFWHN4
# PXSPOUSE
# PENATVTY
# PXNATVTY
# PEMNTVTY
# PXMNTVTY
# PEFNTVTY
# PXFNTVTY
# PEINUSYR
# PXINUSYR
# PEPAR1
# PXPAR1
# PEPAR2
# PXPAR2
# PEPAR1TYP
# PXPAR1TYP
# PEPAR2TYP
# PXPAR2TYP
# PRDASIAN
# PRDTHSP
# PRDTRACE
# PRPERTYP
# PRCITFLG
# PRCITSHP
# PECOHAB
# PXCOHAB
# PEABSRSN
# PEHRUSLT
# PEMLR
# PRDISC
# PRPTREA
# PRUNTYPE
# PRWKSTAT
# PEIO1COW
# PRCOW1
# PRERELG
# PRWERNAL
# PRHERNAL
# PRNLFSCH
# PEDISEAR
# PEDISEYE
# PEDISREM
# PEDISPHY
# PEDISDRS
# PEDISOUT
# PXDISEAR
# PXDISEYE
# PXDISREM
# PXDISPHY
# PXDISDRS
# PXDISOUT
# PRDISFLG
# PECERT1
# PECERT2
# PECERT3
# PXCERT1
# PXCERT2
# PXCERT3
# A_AGE
# A_SEX
# A_DTIND
# A_HRSPAY
# A_PAYABS
# A_WANTJB
# A_HRLYWK
# A_ENRLW
# A_EXPLF
# A_MJIND
# A_UNMEM
# A_MJOCC
# A_DTOCC
# A_UNCOV
# A_HSCOL
# A_FTPT
# ...

# %%
"""
A_AGE = age
A_FNLWGT = fnlwgt
A_SEX = gender
A_MARITL = marital-status
A_PFREL = relationship
A_HGA = education
PRDTRACE = race
PTOT_R (income recode)= income 
A_CLSWKR = class of worker
A_MJOCC = occupation
HRSWK = hours per week
PENATVTY(coded) = native-country
CAP_VAL = capital gain
AGI = adjusted gross income - mainly used to select which rows to keep, nothing else
"""
adult_data_col = ['A_AGE','A_CLSWKR','A_FNLWGT','A_HGA','A_MARITL','A_MJOCC','A_PFREL','PRDTRACE','A_SEX','CAP_VAL','HRSWK','PENATVTY','PTOT_R','AGI']
clean_data = df[adult_data_col]
display(clean_data.head(10))
clean_data.shape
# Out:
#    A_AGE  A_CLSWKR  A_FNLWGT  A_HGA  A_MARITL  A_MJOCC  A_PFREL  PRDTRACE  \
# 0     63         3    166860     39         1        1        2         1
# 1     67         0    193723     39         1        0        1         1
# 2     64         4    111745     39         1       10        1         1
# 3     71         0     99911     36         1        0        2         1
# 4     54         1    151825     39         5        5        0         1
# 5     74         0    157831     39         5        0        5         1
# 6     37         1    174690     39         7        3        3         1
# 7     47         0    113806     42         1        0        2         1
# 8     44         4    156069     40         1        3        1         1
# 9     21         0    153960     39         7        0        3         1
#
#    A_SEX  CAP_VAL  HRSWK  PENATVTY  PTOT_R     AGI
# 0      2        0     40        57      22  124644
# 1      1        0     40        57      30       0
# ...

# %%
#drop all age 16 and under
over16 =  clean_data[clean_data["A_AGE"]>16]
over16.shape
# Out:
# (120114, 14)

# %%
#only keep rows with AGI>100, FNLWGT>1, and HRSWK>0 like the 1994 dataset
over16 = over16[over16["AGI"]>100]
over16 = over16[over16["A_FNLWGT"]>1]
over16 = over16[over16["HRSWK"]>0]
over16.shape
# Out:
# (38576, 14)

# %%
#df["column1"].replace({"a": "x", "b": "y"}, inplace=True)
#convert workclass code to string, similar to adult dataset
over16["A_CLSWKR"].replace({0:"?",1:"Private",2:"Federal-gov",3:"State-gov",4:"Local-gov",5:"Self-emp-inc",6:"Self-emp-not-inc",7:"Without-pay",8:"Never-worked"},inplace=True)
over16.head(10)
# Out:
#     A_AGE   A_CLSWKR  A_FNLWGT  A_HGA  A_MARITL  A_MJOCC  A_PFREL  PRDTRACE  \
# 0      63  State-gov    166860     39         1        1        2         1
# 2      64  Local-gov    111745     39         1       10        1         1
# 4      54    Private    151825     39         5        5        0         1
# 6      37    Private    174690     39         7        3        3         1
# 14     35    Private    197229     41         1        2        2         1
# 25     55          ?    112720     41         1        0        2         1
# 30     36    Private    204560     38         7        3        5         1
# 33     18    Private    152118     38         7        2        3         1
# 35     39    Private    204560     39         7        3        0         1
# 43     53    Private    136143     42         1       10        1         1
#
#     A_SEX  CAP_VAL  HRSWK  PENATVTY  PTOT_R     AGI
# 0       2        0     40        57      22  124644
# ...

# %%
#add educational-num column
edu_num_added = over16.copy()
edu_num_added = edu_num_added[edu_num_added["A_HGA"]!=0]
edu_num_added["educational-num"] = edu_num_added["A_HGA"]
edu_num_added["educational-num"].replace({0:"?",31:1,32:2,33:3,34:4,35:5,36:6,37:7,38:8,39:9,40:10,41:11,42:12,43:13,44:14,45:15,46:16},inplace=True)
cols = edu_num_added.columns.tolist()
rearranged_cols = cols[:4] + cols[-1:] + cols[4:13]
edu_num_added = edu_num_added[rearranged_cols]

# %%
#renaming columns to match adult dataset
renamed_columns = edu_num_added.rename(columns={"A_AGE":"age","A_CLSWKR":"workclass","A_FNLWGT":"fnlwgt","A_HGA":"education","A_MARITL":"marital-status","A_MJOCC":"occupation","A_PFREL":"relationship","PRDTRACE":"race","A_SEX":"gender","CAP_VAL":"capital-gain","HRSWK":"hours-per-week","PENATVTY":"native-country","PTOT_R":"income"})

# %%
#recoding education column
renamed_columns["education"].replace({0:"?",31:"Preschool",32:"1st-4th",33:"5th-6th",34:"7th-8th",35:"9th",36:"10th",37:"11th",38:"12th",39:"HS-grad",40:"Some-college",41:"Assoc-voc",42:"Assoc-acdm",43:"Bachelors",44:"Masters",45:"Prof-school",46:"Doctorate"},inplace=True)
renamed_columns
# Out:
#         age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0        63  State-gov  166860    HS-grad                9               1
# 2        64  Local-gov  111745    HS-grad                9               1
# 4        54    Private  151825    HS-grad                9               5
# 6        37    Private  174690    HS-grad                9               7
# 14       35    Private  197229  Assoc-voc               11               1
# ...     ...        ...     ...        ...              ...             ...
# 157179   41    Private  180857    HS-grad                9               1
# 157183   58    Private  117245    HS-grad                9               1
# 157186   31    Private  126498    HS-grad                9               7
# 157187   57    Private   72015  Bachelors               13               5
# 157189   32    Private   94815    HS-grad                9               7
#
# ...

# %%
renamed_columns.to_csv("2020_ASEC_data_cleaninginprogress.csv",index=False)

# %%
#recoding marital-status
renamed_columns["marital-status"].replace({1:"Married-civ-spouse",2:"Married-AF-spouse",3:"Married-spouse-absent",4:"Widowed",5:"Divorced",6:"Separated",7:"Never-married"},inplace=True)
renamed_columns
# Out:
#         age  workclass  fnlwgt  education  educational-num  \
# 0        63  State-gov  166860    HS-grad                9
# 2        64  Local-gov  111745    HS-grad                9
# 4        54    Private  151825    HS-grad                9
# 6        37    Private  174690    HS-grad                9
# 14       35    Private  197229  Assoc-voc               11
# ...     ...        ...     ...        ...              ...
# 157179   41    Private  180857    HS-grad                9
# 157183   58    Private  117245    HS-grad                9
# 157186   31    Private  126498    HS-grad                9
# 157187   57    Private   72015  Bachelors               13
# 157189   32    Private   94815    HS-grad                9
#
#             marital-status  occupation  relationship  race  gender  \
# 0       Married-civ-spouse           1             2     1       2
# 2       Married-civ-spouse          10             1     1       1
# ...

# %%
#recoding occupation
renamed_columns["occupation"].replace({0:"?",1:"Exec-managerial",2:"Prof-specialty",3:"Other-service",4:"Sales",5:"Adm-clerical",6:"Farming-fishing",7:"Construction",8:"Craft-repair",9:"Production",10:"Transport-moving",11:"Armed-Forces"},inplace=True)
renamed_columns
# Out:
#         age  workclass  fnlwgt  education  educational-num  \
# 0        63  State-gov  166860    HS-grad                9
# 2        64  Local-gov  111745    HS-grad                9
# 4        54    Private  151825    HS-grad                9
# 6        37    Private  174690    HS-grad                9
# 14       35    Private  197229  Assoc-voc               11
# ...     ...        ...     ...        ...              ...
# 157179   41    Private  180857    HS-grad                9
# 157183   58    Private  117245    HS-grad                9
# 157186   31    Private  126498    HS-grad                9
# 157187   57    Private   72015  Bachelors               13
# 157189   32    Private   94815    HS-grad                9
#
#             marital-status        occupation  relationship  race  gender  \
# 0       Married-civ-spouse   Exec-managerial             2     1       2
# 2       Married-civ-spouse  Transport-moving             1     1       1
# ...

# %%
#recoding relationship
renamed_columns["relationship"].replace({0:"Not-in-family",1:"Husband",2:"Wife",3:"Own-child",4:"Other-relative",5:"Unmarried"},inplace=True)
renamed_columns
# Out:
#         age  workclass  fnlwgt  education  educational-num  \
# 0        63  State-gov  166860    HS-grad                9
# 2        64  Local-gov  111745    HS-grad                9
# 4        54    Private  151825    HS-grad                9
# 6        37    Private  174690    HS-grad                9
# 14       35    Private  197229  Assoc-voc               11
# ...     ...        ...     ...        ...              ...
# 157179   41    Private  180857    HS-grad                9
# 157183   58    Private  117245    HS-grad                9
# 157186   31    Private  126498    HS-grad                9
# 157187   57    Private   72015  Bachelors               13
# 157189   32    Private   94815    HS-grad                9
#
#             marital-status        occupation    relationship  race  gender  \
# 0       Married-civ-spouse   Exec-managerial            Wife     1       2
# 2       Married-civ-spouse  Transport-moving         Husband     1       1
# ...

# %%
#recoding race
renamed_columns["race"].replace({1:"White",2:"Black",3:"Amer-Indian-Eskimo",4:"Asian-Pac-Islander",5 :'Other' ,6 :'Other' ,7 :'Other' ,8 :'Other' ,9 :'Other' ,10 :'Other' ,11 :'Other' ,12 :'Other' ,13 :'Other' ,14 :'Other' ,15 :'Other' ,16 :'Other' ,17 :'Other' ,18 :'Other' ,19 :'Other' ,20 :'Other' ,21 :'Other' ,22 :'Other' ,23 :'Other' ,24 :'Other' ,25 :'Other' ,26 :'Other'},inplace=True)
renamed_columns
# Out:
#         age  workclass  fnlwgt  education  educational-num  \
# 0        63  State-gov  166860    HS-grad                9
# 2        64  Local-gov  111745    HS-grad                9
# 4        54    Private  151825    HS-grad                9
# 6        37    Private  174690    HS-grad                9
# 14       35    Private  197229  Assoc-voc               11
# ...     ...        ...     ...        ...              ...
# 157179   41    Private  180857    HS-grad                9
# 157183   58    Private  117245    HS-grad                9
# 157186   31    Private  126498    HS-grad                9
# 157187   57    Private   72015  Bachelors               13
# 157189   32    Private   94815    HS-grad                9
#
#             marital-status        occupation    relationship  \
# 0       Married-civ-spouse   Exec-managerial            Wife
# 2       Married-civ-spouse  Transport-moving         Husband
# 4                 Divorced      Adm-clerical   Not-in-family
# ...

# %%
#recoding gender
renamed_columns["gender"].replace({1:"Male",2:"Female"},inplace=True)
renamed_columns
# Out:
#         age  workclass  fnlwgt  education  educational-num  \
# 0        63  State-gov  166860    HS-grad                9
# 2        64  Local-gov  111745    HS-grad                9
# 4        54    Private  151825    HS-grad                9
# 6        37    Private  174690    HS-grad                9
# 14       35    Private  197229  Assoc-voc               11
# ...     ...        ...     ...        ...              ...
# 157179   41    Private  180857    HS-grad                9
# 157183   58    Private  117245    HS-grad                9
# 157186   31    Private  126498    HS-grad                9
# 157187   57    Private   72015  Bachelors               13
# 157189   32    Private   94815    HS-grad                9
#
#             marital-status        occupation    relationship  \
# 0       Married-civ-spouse   Exec-managerial            Wife
# 2       Married-civ-spouse  Transport-moving         Husband
# 4                 Divorced      Adm-clerical   Not-in-family
# ...

# %%
#recoding income
renamed_columns2 = renamed_columns.rename(columns={"income":"coded-income"})

# %%
#test
for i in range(37,42):
    print(i,":'>90k'",end=",")
# Out:
# 37 :'>90k',38 :'>90k',39 :'>90k',40 :'>90k',41 :'>90k',

# %%
renamed_columns2["income-50k-threshold"] = renamed_columns2["coded-income"]
renamed_columns2["income-90k-threshold"] = renamed_columns2["coded-income"]
renamed_columns2["income-50k-threshold"].replace({0 :'<=50k',1 :'<=50k',2 :'<=50k',3 :'<=50k',4 :'<=50k',5 :'<=50k',6 :'<=50k',7 :'<=50k',8 :'<=50k',9 :'<=50k',10 :'<=50k',11 :'<=50k',12 :'<=50k',13 :'<=50k',14 :'<=50k',15 :'<=50k',16 :'<=50k',17 :'<=50k',18 :'<=50k',19 :'<=50k',20 :'<=50k',21 :'>50k',22 :'>50k',23 :'>50k',24 :'>50k',25 :'>50k',26 :'>50k',27 :'>50k',28 :'>50k',29 :'>50k',30 :'>50k',31 :'>50k',32 :'>50k',33 :'>50k',34 :'>50k',35 :'>50k',36 :'>50k',37 :'>50k',38 :'>50k',39 :'>50k',40 :'>50k',41 :'>50k'},inplace=True)
renamed_columns2["income-90k-threshold"].replace({0 :'<=90k',1 :'<=90k',2 :'<=90k',3 :'<=90k',4 :'<=90k',5 :'<=90k',6 :'<=90k',7 :'<=90k',8 :'<=90k',9 :'<=90k',10 :'<=90k',11 :'<=90k',12 :'<=90k',13 :'<=90k',14 :'<=90k',15 :'<=90k',16 :'<=90k',17 :'<=90k',18 :'<=90k',19 :'<=90k',20 :'<=90k',21 :'<=90k',22 :'<=90k',23 :'<=90k',24 :'<=90k',25 :'<=90k',26 :'<=90k',27 :'<=90k',28 :'<=90k',29 :'<=90k',30 :'<=90k',31 :'<=90k',32 :'<=90k',33 :'<=90k',34 :'<=90k',35 :'<=90k',36 :'<=90k',37 :'>90k',38 :'>90k',39 :'>90k',40 :'>90k',41 :'>90k'},inplace=True)
renamed_columns2
# Out:
#         age  workclass  fnlwgt  education  educational-num  \
# 0        63  State-gov  166860    HS-grad                9
# 2        64  Local-gov  111745    HS-grad                9
# 4        54    Private  151825    HS-grad                9
# 6        37    Private  174690    HS-grad                9
# 14       35    Private  197229  Assoc-voc               11
# ...     ...        ...     ...        ...              ...
# 157179   41    Private  180857    HS-grad                9
# 157183   58    Private  117245    HS-grad                9
# 157186   31    Private  126498    HS-grad                9
# 157187   57    Private   72015  Bachelors               13
# 157189   32    Private   94815    HS-grad                9
#
#             marital-status        occupation    relationship  \
# 0       Married-civ-spouse   Exec-managerial            Wife
# 2       Married-civ-spouse  Transport-moving         Husband
# 4                 Divorced      Adm-clerical   Not-in-family
# ...

# %%
country_code = {57:'United-States',60:'American-Samoa',66:'Guam',69:'Northern-Marianas',73:'Puerto-Rico',78:'U.S.-Virgin-Islands',100:'Albania',102:'Austria',103:'Belgium',104:'Bulgaria',105:'Czechoslovakia',106:'Denmark',108:'Finland',109:'France',110:'Germany',116:'Greece',117:'Hungary',119:'Ireland',120:'Italy',126:'Netherlands',127:'Norway',128:'Poland',129:'Portugal',130:'Azores-',132:'Romania',134:'Spain',136:'Sweden',137:'Switzerland',138:'United-Kingdom',139:'England',140:'Scotland',142:'Northern-Ireland',147:'Yugoslavia',148:'Czech-Republic',149:'Slovakia',150:'Bosnia-&-Herzegovina',151:'Croatia',152:'Macedonia',154:'Serbia',155:'Estonia',156:'Latvia',157:'Lithuania',158:'Armenia',159:'Azerbaijan',160:'Belarus',161:'Georgia',162:'Moldova',163:'Russia',164:'Ukraine',165:'USSR',166:'Europe',168:'Montenegro',200:'Afghanistan',202:'Bangladesh',203:'Bhutan',205:'Myanmar-(Burma)',206:'Cambodia',207:'China',209:'Hong-Kong',210:'India',211:'Indonesia',212:'Iran',213:'Iraq',214:'Israel',215:'Japan',216:'Jordan',217:'Korea',218:'Kazakhstan',220:'South-Korea',222:'Kuwait',223:'Laos',224:'Lebanon',226:'Malaysia',228:'Mongolia',229:'Nepal',231:'Pakistan',233:'Philippines',235:'Saudi-Arabia',236:'Singapore',238:'Sri-Lanka',239:'Syria',240:'Taiwan',242:'Thailand',243:'Turkey',245:'United-Arab-Emirates',246:'Uzbekistan',247:'Vietnam',248:'Yemen',249:'Asia',300:'Bermuda',301:'Canada',303:'Mexico',310:'Belize',311:'Costa-Rica',312:'El-Salvador',313:'Guatemala',314:'Honduras',315:'Nicaragua',316:'Panama',321:'Antigua-and-Barbuda',323:'Bahamas',324:'Barbados',327:'Cuba',328:'Dominica',329:'Dominican-Republic',330:'Grenada',332:'Haiti',333:'Jamaica',338:'St.-Kitts-Nevis',339:'St.-Lucia',340:'St.-Vincent-and-the-Grenadines',341:'Trinidad-and-Tobago',343:'West-Indies',360:'Argentina',361:'Bolivia',362:'Brazil',363:'Chile',364:'Columbia',365:'Ecuador',368:'Guyana',369:'Paraguay',370:'Peru',372:'Uruguay',373:'Venezuela',374:'South-America',399:'Americas',400:'Algeria',407:'Cameroon',408:'Cape-Verde',412:'Congo',414:'Egypt',416:'Ethiopia',417:'Eritrea',421:'Ghana',423:'Guinea',425:'Ivory-Coast',427:'Kenya',429:'Liberia',430:'Libya',436:'Morocco',440:'Nigeria',444:'Senegal',447:'Sierra-Leone',448:'Somalia',449:'South-Africa',451:'Sudan',453:'Tanzania',454:'Togo',457:'Uganda',459:'Zaire',460:'Zambia',461:'Zimbabwe',462:'Africa',501:'Australia',508:'Fiji',511:'Marshall-Islands',512:'Micronesia',515:'New-Zealand',523:'Tonga',527:'Samoa',555:'Elsewhere'}
renamed_columns2["native-country"].replace(country_code,inplace=True)
renamed_columns2
# Out:
#         age  workclass  fnlwgt  education  educational-num  \
# 0        63  State-gov  166860    HS-grad                9
# 2        64  Local-gov  111745    HS-grad                9
# 4        54    Private  151825    HS-grad                9
# 6        37    Private  174690    HS-grad                9
# 14       35    Private  197229  Assoc-voc               11
# ...     ...        ...     ...        ...              ...
# 157179   41    Private  180857    HS-grad                9
# 157183   58    Private  117245    HS-grad                9
# 157186   31    Private  126498    HS-grad                9
# 157187   57    Private   72015  Bachelors               13
# 157189   32    Private   94815    HS-grad                9
#
#             marital-status        occupation    relationship  \
# 0       Married-civ-spouse   Exec-managerial            Wife
# 2       Married-civ-spouse  Transport-moving         Husband
# 4                 Divorced      Adm-clerical   Not-in-family
# ...

# %%
mystring = "057United-States 060American-Samoa 066Guam 069Northern-Marianas 073Puerto-Rico 078U.S.-Virgin-Islands 100Albania 102Austria 103Belgium 104Bulgaria 105Czechoslovakia 106Denmark 108Finland 109France 110Germany 116Greece 117Hungary 119Ireland 120Italy 126Netherlands 127Norway 128Poland 129Portugal 130Azores- 132Romania 134Spain 136Sweden 137Switzerland 138United-Kingdom 139England 140Scotland 142Northern-Ireland 147Yugoslavia 148Czech-Republic 149Slovakia 150Bosnia-&-Herzegovina 151Croatia 152Macedonia 154Serbia 155Estonia 156Latvia 157Lithuania 158Armenia 159Azerbaijan 160Belarus 161Georgia 162Moldova 163Russia 164Ukraine 165USSR 166Europe,-not-specified 168Montenegro 200Afghanistan 202Bangladesh 203Bhutan 205Myanmar-(Burma) 206Cambodia 207China 209Hong-Kong 210India 211Indonesia 212Iran 213Iraq 214Israel 215Japan 216Jordan 217Korea 218Kazakhstan 220South-Korea 222Kuwait 223Laos 224Lebanon 226Malaysia 228Mongolia 229Nepal 231Pakistan 233Philippines 235Saudi-Arabia 236Singapore 238Sri-Lanka 239Syria 240Taiwan 242Thailand 243Turkey 245United-Arab-Emirates 246Uzbekistan 247Vietnam 248Yemen 249Asia,-not-specified 300Bermuda 301Canada 303Mexico 310Belize 311Costa-Rica 312El-Salvador 313Guatemala 314Honduras 315Nicaragua 316Panama 321Antigua-and-Barbuda 323Bahamas 324Barbados 327Cuba 328Dominica 329Dominican-Republic 330Grenada 332Haiti 333Jamaica 338St.-Kitts-Nevis 339St.-Lucia 340St.-Vincent-and-the-Grenadines 341Trinidad-and-Tobago 343West-Indies,-not-specified 360Argentina 361Bolivia 362Brazil 363Chile 364Columbia 365Ecuador 368Guyana 369Paraguay 370Peru 372Uruguay 373Venezuela 374South-America,-not-specified 399Americas,-not-specified 400Algeria 407Cameroon 408Cape-Verde 412Congo 414Egypt 416Ethiopia 417Eritrea 421Ghana 423Guinea 425Ivory-Coast 427Kenya 429Liberia 430Libya 436Morocco 440Nigeria 444Senegal 447Sierra-Leone 448Somalia 449South-Africa 451Sudan 453Tanzania 454Togo 457Uganda 459Zaire 460Zambia 461Zimbabwe 462Africa,-not-specified 501Australia 508Fiji 511Marshall-Islands 512Micronesia 515New-Zealand 523Tonga 527Samoa 555Elsewhere"
mstr_split = mystring.split()
new_string = ""
for each in mstr_split:
    a = each[0:3]+":'"+each[3:]+"',"
    new_string = new_string+a

# %%
renamed_columns2.to_csv("2020_ASEC_version2.csv",index=False)
